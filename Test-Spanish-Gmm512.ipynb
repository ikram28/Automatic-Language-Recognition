# %%
import math
import numpy as np
import joblib

# %%
def split_audio_test(test_mfccs, segment_length_sec):

    # Compute the number of frames per segment
    frames_per_sec = 100  # Assuming 100 frames per second
    frames_per_segment = int(segment_length_sec * frames_per_sec)

    # Split the test audio into segments
    num_segments = math.ceil(len(test_mfccs) / frames_per_segment)
    test_segments = []
    for i in range(num_segments):
        start_frame = i * frames_per_segment
        end_frame = min(start_frame + frames_per_segment, len(test_mfccs))
        segment = test_mfccs[start_frame:end_frame]
        test_segments.append(segment)

    return test_segments

# %%
test_mfccs_russe = np.loadtxt(r'C:\Users\ASUS ROG STRIX\Desktop\Projet\Langues\gmm\Test\spanishTest', delimiter=',')
test_segments_5s_russe = split_audio_test(test_mfccs_russe, 5)
test_segments_10s_russe = split_audio_test(test_mfccs_russe, 10)
test_segments_15s_russe = split_audio_test(test_mfccs_russe, 15)

# %%
# Load the GMM models for each language
russian_gmm512 = joblib.load(r'C:\Users\ASUS ROG STRIX\Desktop\Projet\Langues\gmm\russe\gmm_model512_russe.pkl')
arabic_gmm512 = joblib.load(r'C:\Users\ASUS ROG STRIX\Desktop\Projet\Langues\gmm\arabic\gmm_model512_arabic.pkl')
spanish_gmm512 = joblib.load(r'C:\Users\ASUS ROG STRIX\Desktop\Projet\Langues\gmm\spanish\gmm_model512_spanish.pkl')
english_gmm512 = joblib.load(r'C:\Users\ASUS ROG STRIX\Desktop\Projet\Langues\gmm\english\gmm_model512_english.pkl')
japanese_gmm512 = joblib.load(r'C:\Users\ASUS ROG STRIX\Desktop\Projet\Langues\gmm\japanese\gmm_model512_japanese.pkl')
french_gmm512 = joblib.load(r'C:\Users\ASUS ROG STRIX\Desktop\Projet\Langues\gmm\french\gmm_model512_french.pkl')

# %%
def predict_language(mfccs, russian_gmm, arabic_gmm, spanish_gmm, english_gmm, japanese_gmm, french_gmm):

    
    # calculate the scores for each language
    russian_score = russian_gmm.score_samples(mfccs)
    arabic_score = arabic_gmm.score_samples(mfccs)
    spanish_score = spanish_gmm.score_samples(mfccs)
    english_score = english_gmm.score_samples(mfccs)
    japanese_score = japanese_gmm.score_samples(mfccs)
    french_score = french_gmm.score_samples(mfccs)
    
    # return the language with the highest score
    scores = {"russian": russian_score.mean(), "arabic": arabic_score.mean(), "spanish": spanish_score.mean(), 
              "english": english_score.mean(), "japanese": japanese_score.mean(), "french": french_score.mean()}
    predicted_language = max(scores, key=scores.get)
    max_score = scores[predicted_language]


    return  max_score , predicted_language

# %%
results5s = []
for test_segment in test_segments_5s_russe:
    mydict = {}
    mydict["maxScore"], mydict["predictedLanguage"] = predict_language(test_segment, russian_gmm512, arabic_gmm512, 
                                                                   spanish_gmm512, english_gmm512, japanese_gmm512, 
                                                                   french_gmm512)
    results5s.append(mydict)
    
for result in results5s:
    print("MAX_Score:", result["maxScore"] ,"--- Predicted Language:", result["predictedLanguage"] )
# Out:
# MAX_Score: -51.2828104650212 --- Predicted Language: french
# MAX_Score: -54.35360259445891 --- Predicted Language: french
# MAX_Score: -54.282959336082115 --- Predicted Language: french
# MAX_Score: -53.20872933042 --- Predicted Language: french
# MAX_Score: -53.90772563710436 --- Predicted Language: french
# MAX_Score: -54.45808687497738 --- Predicted Language: french
# MAX_Score: -54.28189675863122 --- Predicted Language: french
# MAX_Score: -52.978076347814934 --- Predicted Language: french
# MAX_Score: -54.22729535910809 --- Predicted Language: spanish
# MAX_Score: -53.214217238530736 --- Predicted Language: french
# MAX_Score: -56.01395094680623 --- Predicted Language: spanish
# MAX_Score: -34.4419511928536 --- Predicted Language: spanish
# MAX_Score: -34.56907031315872 --- Predicted Language: spanish
# MAX_Score: -45.39662969509825 --- Predicted Language: spanish
# MAX_Score: -50.82649208089225 --- Predicted Language: spanish
# MAX_Score: -50.26718312306128 --- Predicted Language: spanish
# MAX_Score: -51.27833395682276 --- Predicted Language: spanish
# MAX_Score: -50.65894171927235 --- Predicted Language: spanish
# MAX_Score: -50.6776667831014 --- Predicted Language: spanish
# MAX_Score: -51.07386936930209 --- Predicted Language: spanish
# MAX_Score: -51.2820925646715 --- Predicted Language: spanish
# MAX_Score: -51.03041926065566 --- Predicted Language: spanish
# MAX_Score: -50.89723736030364 --- Predicted Language: spanish
# MAX_Score: -51.08679798882517 --- Predicted Language: spanish
# MAX_Score: -50.85833022136806 --- Predicted Language: spanish
# MAX_Score: -51.78180533608071 --- Predicted Language: spanish
# MAX_Score: -51.32573564225325 --- Predicted Language: spanish
# MAX_Score: -41.474033826399626 --- Predicted Language: spanish
# MAX_Score: -52.23680068723377 --- Predicted Language: spanish
# MAX_Score: -50.83891803399708 --- Predicted Language: spanish
# MAX_Score: -51.46356096419557 --- Predicted Language: spanish
# MAX_Score: -51.77683443996895 --- Predicted Language: spanish
# MAX_Score: -51.50270427030203 --- Predicted Language: spanish
# MAX_Score: -51.1619664887668 --- Predicted Language: spanish
# MAX_Score: -50.83277873126969 --- Predicted Language: spanish
# MAX_Score: -51.480395791944346 --- Predicted Language: spanish
# MAX_Score: -51.31209512737315 --- Predicted Language: spanish
# MAX_Score: -51.08840167491911 --- Predicted Language: spanish
# MAX_Score: -50.901373499712 --- Predicted Language: spanish
# MAX_Score: -51.602517970494475 --- Predicted Language: spanish
# MAX_Score: -52.77014014705887 --- Predicted Language: spanish
# MAX_Score: -47.540017400442856 --- Predicted Language: spanish
# MAX_Score: -49.14016815753019 --- Predicted Language: spanish
# MAX_Score: -48.97179449024852 --- Predicted Language: spanish
# MAX_Score: -48.91957312594968 --- Predicted Language: spanish
# MAX_Score: -47.934400346908745 --- Predicted Language: spanish
# MAX_Score: -48.45081518590898 --- Predicted Language: spanish
# MAX_Score: -48.89047440358785 --- Predicted Language: spanish
# MAX_Score: -49.28382169151391 --- Predicted Language: spanish
# MAX_Score: -48.21796904771449 --- Predicted Language: spanish
# MAX_Score: -49.027504442560065 --- Predicted Language: spanish
# MAX_Score: -48.581568584533045 --- Predicted Language: spanish
# MAX_Score: -48.585877450351234 --- Predicted Language: spanish
# MAX_Score: -48.44336646028825 --- Predicted Language: spanish
# MAX_Score: -48.23727359598351 --- Predicted Language: spanish
# MAX_Score: -48.199740716121084 --- Predicted Language: spanish
# MAX_Score: -48.82187797554048 --- Predicted Language: spanish
# MAX_Score: -48.29735971781922 --- Predicted Language: spanish
# MAX_Score: -48.2147914843833 --- Predicted Language: spanish
# MAX_Score: -48.58847290738467 --- Predicted Language: spanish
# MAX_Score: -46.504835787366915 --- Predicted Language: spanish
# MAX_Score: -46.26286043292636 --- Predicted Language: spanish
# MAX_Score: -45.83536120719515 --- Predicted Language: spanish
# MAX_Score: -46.16677623637223 --- Predicted Language: spanish
# MAX_Score: -48.675297118956166 --- Predicted Language: spanish
# MAX_Score: -46.8511624634331 --- Predicted Language: spanish
# MAX_Score: -47.40812271556954 --- Predicted Language: spanish
# MAX_Score: -45.031436938228175 --- Predicted Language: spanish
# MAX_Score: -46.86446951613926 --- Predicted Language: spanish
# MAX_Score: -44.153340756253826 --- Predicted Language: spanish
# MAX_Score: -47.76898757227046 --- Predicted Language: spanish
# MAX_Score: -47.5218317171909 --- Predicted Language: spanish
# MAX_Score: -45.04360545526663 --- Predicted Language: spanish
# MAX_Score: -45.45451729682032 --- Predicted Language: spanish
# MAX_Score: -45.98315690670225 --- Predicted Language: spanish
# MAX_Score: -47.34229221839902 --- Predicted Language: spanish
# MAX_Score: -46.23076460009119 --- Predicted Language: spanish
# MAX_Score: -46.556055947239564 --- Predicted Language: spanish
# MAX_Score: -45.60647639443959 --- Predicted Language: spanish
# MAX_Score: -45.35057505376813 --- Predicted Language: spanish
# MAX_Score: -45.25559930941258 --- Predicted Language: spanish
# MAX_Score: -46.428107362430104 --- Predicted Language: spanish
# MAX_Score: -46.483884895643975 --- Predicted Language: spanish
# MAX_Score: -45.61133604551509 --- Predicted Language: spanish
# MAX_Score: -45.690153297374465 --- Predicted Language: spanish
# MAX_Score: -47.648527860758755 --- Predicted Language: spanish
# MAX_Score: -46.12289105006956 --- Predicted Language: spanish
# MAX_Score: -49.37737764444939 --- Predicted Language: spanish
# MAX_Score: -45.532584168142506 --- Predicted Language: spanish
# MAX_Score: -46.396139927516096 --- Predicted Language: spanish
# MAX_Score: -46.136698242067304 --- Predicted Language: spanish
# MAX_Score: -47.37028051314362 --- Predicted Language: spanish
# MAX_Score: -47.73731391891192 --- Predicted Language: spanish
# MAX_Score: -45.971666272726736 --- Predicted Language: spanish
# MAX_Score: -45.85716858222689 --- Predicted Language: spanish
# MAX_Score: -46.061832905426535 --- Predicted Language: spanish
# MAX_Score: -45.91102052710331 --- Predicted Language: spanish
# MAX_Score: -46.274496799798776 --- Predicted Language: spanish
# MAX_Score: -46.82242451597548 --- Predicted Language: spanish
# MAX_Score: -46.26735414580812 --- Predicted Language: spanish
# MAX_Score: -46.28331150937995 --- Predicted Language: spanish
# MAX_Score: -48.07554587072894 --- Predicted Language: spanish
# MAX_Score: -47.47577047856 --- Predicted Language: spanish
# MAX_Score: -45.6620985819445 --- Predicted Language: spanish
# MAX_Score: -47.54366171292195 --- Predicted Language: spanish
# MAX_Score: -50.56873998729767 --- Predicted Language: spanish
# MAX_Score: -50.217127666547064 --- Predicted Language: spanish
# MAX_Score: -48.884291153623096 --- Predicted Language: spanish
# MAX_Score: -48.686005059040106 --- Predicted Language: spanish
# MAX_Score: -47.208816455170826 --- Predicted Language: spanish
# MAX_Score: -47.42316491629387 --- Predicted Language: spanish
# MAX_Score: -48.83857342272003 --- Predicted Language: spanish
# MAX_Score: -50.033798233401164 --- Predicted Language: spanish
# MAX_Score: -47.03738859312296 --- Predicted Language: spanish
# MAX_Score: -47.78667230811146 --- Predicted Language: spanish
# MAX_Score: -46.765357991444276 --- Predicted Language: spanish
# MAX_Score: -47.39253291465966 --- Predicted Language: spanish
# MAX_Score: -47.10772108748232 --- Predicted Language: spanish
# MAX_Score: -46.88504604794468 --- Predicted Language: spanish
# MAX_Score: -47.41694642942196 --- Predicted Language: spanish
# MAX_Score: -46.04444872548895 --- Predicted Language: spanish
# MAX_Score: -47.15016200849121 --- Predicted Language: spanish
# MAX_Score: -47.038037216413755 --- Predicted Language: spanish
# MAX_Score: -46.92662735142432 --- Predicted Language: spanish
# MAX_Score: -47.693710560275356 --- Predicted Language: spanish
# MAX_Score: -47.908869672196346 --- Predicted Language: spanish
# MAX_Score: -46.90117013784489 --- Predicted Language: spanish
# MAX_Score: -46.320005269225355 --- Predicted Language: spanish
# MAX_Score: -45.99036594448547 --- Predicted Language: spanish
# MAX_Score: -48.72525856963733 --- Predicted Language: spanish
# MAX_Score: -49.02776118034724 --- Predicted Language: spanish
# MAX_Score: -45.514710486435305 --- Predicted Language: spanish
# MAX_Score: -47.22624680979522 --- Predicted Language: spanish
# MAX_Score: -46.4822280639276 --- Predicted Language: spanish
# MAX_Score: -48.60937480055699 --- Predicted Language: spanish
# MAX_Score: -48.16295158771397 --- Predicted Language: spanish
# MAX_Score: -47.614049325822926 --- Predicted Language: spanish
# MAX_Score: -47.85599837599878 --- Predicted Language: spanish
# MAX_Score: -46.723678611401205 --- Predicted Language: spanish
# MAX_Score: -47.86148451802217 --- Predicted Language: spanish
# MAX_Score: -48.0753809415863 --- Predicted Language: spanish
# MAX_Score: -46.91509526949751 --- Predicted Language: spanish
# MAX_Score: -46.54852856246279 --- Predicted Language: spanish
# MAX_Score: -47.85867319270529 --- Predicted Language: spanish
# MAX_Score: -46.535311321318176 --- Predicted Language: spanish
# MAX_Score: -45.398785740021424 --- Predicted Language: spanish
# MAX_Score: -48.12857010126071 --- Predicted Language: spanish
# MAX_Score: -46.889518086304456 --- Predicted Language: spanish
# MAX_Score: -48.26129015783535 --- Predicted Language: spanish
# MAX_Score: -46.193376831996794 --- Predicted Language: spanish
# MAX_Score: -44.631870136920014 --- Predicted Language: spanish
# MAX_Score: -49.62611471968761 --- Predicted Language: spanish
# MAX_Score: -45.85120910839783 --- Predicted Language: spanish
# MAX_Score: -44.83608351577538 --- Predicted Language: spanish
# MAX_Score: -46.63592324047705 --- Predicted Language: spanish
# MAX_Score: -46.78919855899228 --- Predicted Language: spanish
# MAX_Score: -46.481764762283895 --- Predicted Language: spanish
# MAX_Score: -44.658791827435735 --- Predicted Language: spanish
# MAX_Score: -46.391400974050875 --- Predicted Language: spanish
# MAX_Score: -45.599869538092165 --- Predicted Language: spanish
# MAX_Score: -47.13923514238841 --- Predicted Language: spanish
# MAX_Score: -47.08632791227019 --- Predicted Language: spanish
# MAX_Score: -45.59816397939256 --- Predicted Language: spanish
# MAX_Score: -45.761444689107314 --- Predicted Language: spanish
# MAX_Score: -46.670456006403406 --- Predicted Language: spanish
# MAX_Score: -44.68413594694614 --- Predicted Language: spanish
# MAX_Score: -45.67692593055206 --- Predicted Language: spanish
# MAX_Score: -44.6467117476875 --- Predicted Language: spanish
# MAX_Score: -46.639802681648796 --- Predicted Language: spanish
# MAX_Score: -47.90776907792301 --- Predicted Language: spanish
# MAX_Score: -46.615999406188514 --- Predicted Language: spanish

# %%
results10s = []
for test_segment in test_segments_10s_russe:
    mydict = {}
    mydict["maxScore"], mydict["predictedLanguage"] = predict_language(test_segment, russian_gmm512, arabic_gmm512, 
                                                                   spanish_gmm512, english_gmm512, japanese_gmm512, 
                                                                   french_gmm512)
    results10s.append(mydict)
    
for result in results10s:
    print("MAX_Score:", result["maxScore"] ,"--- Predicted Language:", result["predictedLanguage"] )
# Out:
# MAX_Score: -52.81820652974005 --- Predicted Language: french
# MAX_Score: -53.74584433325105 --- Predicted Language: french
# MAX_Score: -54.18290625604087 --- Predicted Language: french
# MAX_Score: -53.62998655322308 --- Predicted Language: french
# MAX_Score: -53.96791123100373 --- Predicted Language: french
# MAX_Score: -45.22795106982991 --- Predicted Language: spanish
# MAX_Score: -39.98285000412849 --- Predicted Language: spanish
# MAX_Score: -50.546837601976776 --- Predicted Language: spanish
# MAX_Score: -50.96863783804755 --- Predicted Language: spanish
# MAX_Score: -50.87576807620174 --- Predicted Language: spanish
# MAX_Score: -51.156255912663575 --- Predicted Language: spanish
# MAX_Score: -50.9920176745644 --- Predicted Language: spanish
# MAX_Score: -51.32006777872438 --- Predicted Language: spanish
# MAX_Score: -46.399884734326434 --- Predicted Language: spanish
# MAX_Score: -51.53785936061543 --- Predicted Language: spanish
# MAX_Score: -51.620197702082265 --- Predicted Language: spanish
# MAX_Score: -51.33233537953441 --- Predicted Language: spanish
# MAX_Score: -51.156587261607015 --- Predicted Language: spanish
# MAX_Score: -51.200248401146126 --- Predicted Language: spanish
# MAX_Score: -51.25194573510324 --- Predicted Language: spanish
# MAX_Score: -50.155078773750866 --- Predicted Language: spanish
# MAX_Score: -49.055981323889355 --- Predicted Language: spanish
# MAX_Score: -48.426986736429214 --- Predicted Language: spanish
# MAX_Score: -48.67064479474842 --- Predicted Language: spanish
# MAX_Score: -48.7508953696142 --- Predicted Language: spanish
# MAX_Score: -48.80453651354655 --- Predicted Language: spanish
# MAX_Score: -48.51462195531975 --- Predicted Language: spanish
# MAX_Score: -48.2185071560523 --- Predicted Language: spanish
# MAX_Score: -48.55961884667985 --- Predicted Language: spanish
# MAX_Score: -48.401632195883984 --- Predicted Language: spanish
# MAX_Score: -46.383848110146644 --- Predicted Language: spanish
# MAX_Score: -46.00106872178369 --- Predicted Language: spanish
# MAX_Score: -47.76322979119464 --- Predicted Language: spanish
# MAX_Score: -46.21977982689886 --- Predicted Language: spanish
# MAX_Score: -45.50890513619654 --- Predicted Language: spanish
# MAX_Score: -47.64540964473068 --- Predicted Language: spanish
# MAX_Score: -45.24906137604348 --- Predicted Language: spanish
# MAX_Score: -46.662724562550636 --- Predicted Language: spanish
# MAX_Score: -46.39341027366539 --- Predicted Language: spanish
# MAX_Score: -45.478525724103854 --- Predicted Language: spanish
# MAX_Score: -45.84185333592135 --- Predicted Language: spanish
# MAX_Score: -46.04761047057953 --- Predicted Language: spanish
# MAX_Score: -46.669340579066606 --- Predicted Language: spanish
# MAX_Score: -47.750134347259475 --- Predicted Language: spanish
# MAX_Score: -45.9643620478293 --- Predicted Language: spanish
# MAX_Score: -46.75348937760546 --- Predicted Language: spanish
# MAX_Score: -46.85449009581933 --- Predicted Language: spanish
# MAX_Score: -45.95950074382672 --- Predicted Language: spanish
# MAX_Score: -46.09275866345105 --- Predicted Language: spanish
# MAX_Score: -46.544889330891806 --- Predicted Language: spanish
# MAX_Score: -47.17942869005444 --- Predicted Language: spanish
# MAX_Score: -46.56893453025225 --- Predicted Language: spanish
# MAX_Score: -49.05620085010981 --- Predicted Language: spanish
# MAX_Score: -49.550709410085084 --- Predicted Language: spanish
# MAX_Score: -47.947410757105466 --- Predicted Language: spanish
# MAX_Score: -48.13086916950695 --- Predicted Language: spanish
# MAX_Score: -48.53559341326206 --- Predicted Language: spanish
# MAX_Score: -47.27601514977787 --- Predicted Language: spanish
# MAX_Score: -47.25012700107099 --- Predicted Language: spanish
# MAX_Score: -47.15099623868332 --- Predicted Language: spanish
# MAX_Score: -46.59730536699008 --- Predicted Language: spanish
# MAX_Score: -46.982332283919035 --- Predicted Language: spanish
# MAX_Score: -47.80129011623585 --- Predicted Language: spanish
# MAX_Score: -46.610587703535124 --- Predicted Language: spanish
# MAX_Score: -47.357812257061404 --- Predicted Language: spanish
# MAX_Score: -47.27123583339127 --- Predicted Language: spanish
# MAX_Score: -46.85423743686141 --- Predicted Language: spanish
# MAX_Score: -48.386163194135484 --- Predicted Language: spanish
# MAX_Score: -47.735023850910856 --- Predicted Language: spanish
# MAX_Score: -47.292581564711696 --- Predicted Language: spanish
# MAX_Score: -47.49523810554191 --- Predicted Language: spanish
# MAX_Score: -47.203600877584044 --- Predicted Language: spanish
# MAX_Score: -45.9670485306698 --- Predicted Language: spanish
# MAX_Score: -47.50904409378259 --- Predicted Language: spanish
# MAX_Score: -47.227333494916074 --- Predicted Language: spanish
# MAX_Score: -47.1289924283038 --- Predicted Language: spanish
# MAX_Score: -45.34364631208661 --- Predicted Language: spanish
# MAX_Score: -46.71256089973466 --- Predicted Language: spanish
# MAX_Score: -45.57027829485982 --- Predicted Language: spanish
# MAX_Score: -45.995635256071516 --- Predicted Language: spanish
# MAX_Score: -47.1127815273293 --- Predicted Language: spanish
# MAX_Score: -45.67980433424994 --- Predicted Language: spanish
# MAX_Score: -45.67729597667478 --- Predicted Language: spanish
# MAX_Score: -45.161818839119775 --- Predicted Language: spanish
# MAX_Score: -47.27378587978589 --- Predicted Language: spanish
# MAX_Score: -46.615999406188514 --- Predicted Language: spanish

# %%
results15s = []
for test_segment in test_segments_15s_russe:
    mydict = {}
    mydict["maxScore"], mydict["predictedLanguage"] = predict_language(test_segment, russian_gmm512, arabic_gmm512, 
                                                                   spanish_gmm512, english_gmm512, japanese_gmm512, 
                                                                   french_gmm512)
    results15s.append(mydict)
    
for result in results15s:
    print("MAX_Score:", result["maxScore"] ,"--- Predicted Language:", result["predictedLanguage"] )
# Out:
# MAX_Score: -53.306457465187414 --- Predicted Language: french
# MAX_Score: -53.85818061416724 --- Predicted Language: french
# MAX_Score: -53.99385944330762 --- Predicted Language: french
# MAX_Score: -48.785613743953824 --- Predicted Language: spanish
# MAX_Score: -43.59739736304974 --- Predicted Language: spanish
# MAX_Score: -50.7348195997188 --- Predicted Language: spanish
# MAX_Score: -51.011209572358325 --- Predicted Language: spanish
# MAX_Score: -51.00481820326149 --- Predicted Language: spanish
# MAX_Score: -51.32195706656734 --- Predicted Language: spanish
# MAX_Score: -48.183250849210154 --- Predicted Language: spanish
# MAX_Score: -51.581033224822185 --- Predicted Language: spanish
# MAX_Score: -51.158380337326946 --- Predicted Language: spanish
# MAX_Score: -51.10062343400143 --- Predicted Language: spanish
# MAX_Score: -50.63755850599873 --- Predicted Language: spanish
# MAX_Score: -49.01051192457613 --- Predicted Language: spanish
# MAX_Score: -48.42522997880186 --- Predicted Language: spanish
# MAX_Score: -48.84309839392948 --- Predicted Language: spanish
# MAX_Score: -48.53693749839085 --- Predicted Language: spanish
# MAX_Score: -48.41963076254836 --- Predicted Language: spanish
# MAX_Score: -48.36687470319572 --- Predicted Language: spanish
# MAX_Score: -46.201019142496136 --- Predicted Language: spanish
# MAX_Score: -47.23107860625383 --- Predicted Language: spanish
# MAX_Score: -46.434676389978996 --- Predicted Language: spanish
# MAX_Score: -46.48138668190506 --- Predicted Language: spanish
# MAX_Score: -45.49375988626307 --- Predicted Language: spanish
# MAX_Score: -46.70970425524326 --- Predicted Language: spanish
# MAX_Score: -45.40421691920676 --- Predicted Language: spanish
# MAX_Score: -46.174442767863056 --- Predicted Language: spanish
# MAX_Score: -46.487190736067596 --- Predicted Language: spanish
# MAX_Score: -47.10203391336932 --- Predicted Language: spanish
# MAX_Score: -47.08143089137428 --- Predicted Language: spanish
# MAX_Score: -45.96355592012672 --- Predicted Language: spanish
# MAX_Score: -46.33598061429253 --- Predicted Language: spanish
# MAX_Score: -46.87540384197233 --- Predicted Language: spanish
# MAX_Score: -46.893843591142144 --- Predicted Language: spanish
# MAX_Score: -49.89005293582262 --- Predicted Language: spanish
# MAX_Score: -47.7726621435016 --- Predicted Language: spanish
# MAX_Score: -48.63658674974805 --- Predicted Language: spanish
# MAX_Score: -47.31485440473846 --- Predicted Language: spanish
# MAX_Score: -47.136571188282986 --- Predicted Language: spanish
# MAX_Score: -46.744215983464635 --- Predicted Language: spanish
# MAX_Score: -47.509735861298665 --- Predicted Language: spanish
# MAX_Score: -46.403847117185244 --- Predicted Language: spanish
# MAX_Score: -47.75591007880663 --- Predicted Language: spanish
# MAX_Score: -47.43928322475994 --- Predicted Language: spanish
# MAX_Score: -47.87766642984523 --- Predicted Language: spanish
# MAX_Score: -47.553514690336556 --- Predicted Language: spanish
# MAX_Score: -47.10743234155521 --- Predicted Language: spanish
# MAX_Score: -46.687555720866776 --- Predicted Language: spanish
# MAX_Score: -47.114728358712206 --- Predicted Language: spanish
# MAX_Score: -46.70306465500182 --- Predicted Language: spanish
# MAX_Score: -46.0870684384149 --- Predicted Language: spanish
# MAX_Score: -45.843985854590166 --- Predicted Language: spanish
# MAX_Score: -46.60847753091692 --- Predicted Language: spanish
# MAX_Score: -46.0100215583011 --- Predicted Language: spanish
# MAX_Score: -45.00259120839524 --- Predicted Language: spanish
# MAX_Score: -47.22562542435106 --- Predicted Language: spanish

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Get the predicted scores and true labels for spanish with different thresholds
scores5s = [result["maxScore"] for result in results5s]
labels5s = [1 if result["predictedLanguage"] == "spanish" else 0 for result in results5s]

scores10s = [result["maxScore"] for result in results10s]
labels10s = [1 if result["predictedLanguage"] == "spanish" else 0 for result in results10s]

scores15s = [result["maxScore"] for result in results15s]
labels15s = [1 if result["predictedLanguage"] == "spanish" else 0 for result in results15s]

# Compute the FPR, TPR, and AUC for each ROC curve
fpr5s, tpr5s, thresholds5s = roc_curve(labels5s, scores5s)
roc_auc5s = auc(fpr5s, tpr5s)

fpr10s, tpr10s, thresholds10s = roc_curve(labels10s, scores10s)
roc_auc10s = auc(fpr10s, tpr10s)
fpr15s, tpr15s, thresholds15s = roc_curve(labels15s, scores15s)
roc_auc15s = auc(fpr15s, tpr15s)

# Plot the ROC curves on the same figure
plt.figure()
plt.plot(fpr5s, tpr5s, color='darkorange', lw=2, label='ROC curve with threshold=5s (area = %0.2f)' % roc_auc5s)
plt.plot(fpr10s, tpr10s, color='green', lw=2, label='ROC curve with threshold=10s (area = %0.2f)' % roc_auc10s)
plt.plot(fpr15s, tpr15s, color='blue', lw=2, label='ROC curve with threshold=15s (area = %0.2f)' % roc_auc15s)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) for Spanish language detection')
plt.legend(loc="lower right")
plt.show()
